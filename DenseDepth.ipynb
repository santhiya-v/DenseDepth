# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
from multiprocessing import Process
os.chdir("/content/gdrive/My Drive/EVA/15A/DenseDepth/")

# %%
# !python test.py --input "./../fg_bg.zip" --model "./nyu_1.h5" --output "./../dense_depth_out"
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (./nyu_1.h5).
# Processing BG :  1
# Batch  1  started..
# Batch  2  started..
# Batch  3  started..
# Batch  4  started..
# Batch  5  started..
# Batch  6  started..
# Batch  7  started..
# Batch  8  started..
# Processing BG :  2
# Batch  1  started..
# Batch  2  started..
# Batch  3  started..
# Batch  4  started..
# Batch  5  started..
# Batch  6  started..
# Batch  7  started..
# Batch  8  started..
# Processing BG :  3
# Batch  1  started..
# Batch  2  started..
# Batch  3  started..
# Batch  4  started..
# Batch  5  started..
# Batch  6  started..
# Batch  7  started..
# Batch  8  started..
# Processing BG :  4
# Batch  1  started..
# Batch  2  started..
# Batch  3  started..
# Batch  4  started..
# Batch  5  started..
# Batch  6  started..
# Batch  7  started..
# Batch  8  started..
# Processing BG :  5
# Batch  1  started..
# Batch  2  started..
# Batch  3  started..
# Batch  4  started..
# Batch  5  started..
# ...
