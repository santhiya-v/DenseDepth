# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
from multiprocessing import Process
os.chdir("/content/gdrive/My Drive/EVA/15A/DenseDepth/")

# %%
# !python test.py --input "./../fg_bg.zip" --model "./nyu.h5" --output "./../dense_depth_out"
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (./nyu.h5).
# Processing BG :  1
# Batch  1  started..
# tcmalloc: large alloc 1204224000 bytes == 0x83e96000 @  0x7f378c8e51e7 0x7f378931a5e1 0x7f378937ec78 0x7f378937ed93 0x7f378941cea8 0x7f378941d704 0x7f378941d852 0x566d63 0x59fc4e 0x7f378936a4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588d41 0x59fc4e 0x7f378936a4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x509758 0x50a48d
# Batch  2  started..
# Batch  3  started..
# Batch  4  started..
# Batch  5  started..
# Batch  6  started..
# Batch  7  started..
# Batch  8  started..
# Batch  9  started..
# Batch  10  started..
# Batch  11  started..
# Batch  12  started..
# Batch  13  started..
# Batch  14  started..
# Batch  15  started..
# Batch  16  started..
# --- 5 Mins ---
# Processing BG :  2
# Batch  1  started..
# Batch  2  started..
# Batch  3  started..
# Batch  4  started..
# Batch  5  started..
# ...
